# %% [markdown]
# <a href="https://colab.research.google.com/github/MSharathChandra815/MyProject/blob/main/OPEN_CV_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

from IPython.display import Image
from google.colab.patches import cv2_imshow

# %matplotlib inline

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/qhhlqcica1nvtaw/opencv_bootcamp_assets_NB1.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), "opencv_bootcamp_assets_NB1.zip")

# Download if assest ZIP does not exists.
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# # **Question No 1:  Display First images from the dataset(1-10 images)**

# %%
Image(filename="checkerboard_18x18.png")

# %%
Image(filename="checkerboard_84x84.jpg")

# %%
Image(filename="New_Zealand_Lake.jpg")

# %%
Image(filename="checkerboard_color.png")

# %%
Image(filename="checkerboard_fuzzy_18x18.jpg")

# %%
Image(filename="coca-cola-logo.png")

# %% [markdown]
# # **Question No:2 Display the image by using cv2 imshow**

# %%
image=cv2.imread("coca-cola.jpg",1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x879>

# %%
# Read in image
coke_img = cv2.imread("coca-cola.jpg", 1)
print(coke_img)
# print the size  of image
print("Image size (H, W, C) is:", coke_img.shape)

# print data-type of image
print("Data type of image is:", coke_img.dtype)
# Out:
# [[[ 35  24 188]
#   [ 35  24 188]
#   [ 35  24 188]
#   ...
#   [ 36  24 190]
#   [ 36  24 190]
#   [ 39  25 191]]
#
#  [[ 35  24 188]
#   [ 35  24 188]
#   [ 35  24 188]
#   ...
#   [ 36  24 190]
#   [ 36  24 190]
#   [ 39  25 191]]
#
#  [[ 35  24 188]
#   [ 35  24 188]
#   [ 35  24 188]
#   ...
#   [ 36  24 190]
#   [ 36  24 190]
#   [ 39  25 191]]
#
#  ...
#
#  [[ 26  12 160]
#   [ 26  12 160]
#   [ 26  12 160]
#   ...
#   [ 27  15 165]
#   [ 27  15 165]
#   [ 31  14 165]]
#
#  [[ 26  12 160]
#   [ 26  12 160]
#   [ 26  12 160]
#   ...
#   [ 27  15 165]
#   [ 27  15 165]
#   [ 31  14 165]]
#
#  [[ 26  12 160]
#   [ 26  12 160]
#   [ 26  12 160]
#   ...
#   [ 27  15 165]
#   [ 27  15 165]
#   [ 31  14 165]]]
# Image size (H, W, C) is: (879, 1200, 3)
# Data type of image is: uint8

# %% [markdown]
# ## **Question No 3:Crop the name Coca-cola and below lines from the Coca-cola logo image**

# %%
plt.imshow(coke_img)

# %%
coke_img_channels_reversed = coke_img[:, :, ::-1]
plt.imshow(coke_img_channels_reversed)

# %% [markdown]
# # **Question No4: Plot the red, Green, blue, BGR and RGB images**

# %%
img_CC = cv2.imread("coca-cola.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_CC)

# Show the channels
plt.figure(figsize=[20, 5])

plt.subplot(151);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(152);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(153);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

imgMerged = cv2.merge((b, g, r))

plt.subplot(154);plt.imshow(imgMerged);plt.title("BGR")

imgMerged = cv2.merge((r, g, b))

plt.subplot(155);plt.imshow(imgMerged);plt.title("RGB")
# Out:
# Text(0.5, 1.0, 'RGB')

# %% [markdown]
# ## **Question No 5: Plot the both RGB and BGR images of Coco-cola logo**

# %%
img_CC_BGR_RGB= cv2.imread("coca-cola.jpg", 1)
plt.subplot(121);plt.imshow(img_CC_BGR_RGB);plt.title("BGR")
plt.subplot(122);plt.imshow(img_CC_BGR_RGB[:,:,::-1]);plt.title("RGB")
# Out:
# Text(0.5, 1.0, 'RGB')

# %% [markdown]
# ## **Question No 6:Plot the BGR2RGB and RGB2BGR images**

# %%
coca_RGB = cv2.cvtColor(img_CC, cv2.COLOR_BGR2RGB)
plt.subplot(121);plt.imshow(coca_RGB);plt.title("BGR2RGB")
coca_BGR = cv2.cvtColor(coca_RGB, cv2.COLOR_RGB2BGR)
plt.subplot(122);plt.imshow(coca_RGB);plt.title("RGB2BGR")
# Out:
# Text(0.5, 1.0, 'RGB2BGR')

# %% [markdown]
# ## **Question No 7:  Save the images in the file name bvrit_cv_ex1.png**

# %%
img_NZ_rgb = cv2.imread("coca-cola.jpg")

# %%
cv2.imwrite("bvrit_cv_ex1.png",img_NZ_rgb)
Image(filename='bvrit_cv_ex1.png')

# %% [markdown]
# ## **Question No 8: Plot the Gray scale image and color image**

# %%
img_NZ_rgb = cv2.imread("bvrit_cv_ex1.png",cv2.IMREAD_COLOR)
print("img_NZ_rgb shape (H,W,C) is: ", img_NZ_rgb.shape)

img_NZ_gry = cv2.imread("bvrit_cv_ex1.png",cv2.IMREAD_GRAYSCALE)
print("img_NZ_rgb shape (H,W,C) is: ", img_NZ_gry.shape)
# Out:
# img_NZ_rgb shape (H,W,C) is:  (879, 1200, 3)
# img_NZ_rgb shape (H,W,C) is:  (879, 1200)

# %%
plt.figure(figsize=[20,5])
plt.subplot(131);plt.imshow(img_NZ_gry,cmap='gray');plt.title("Gray Scale Image");
plt.subplot(132);plt.imshow(img_NZ_rgb);plt.title("Color Image");

img_NZ_bgr=img_NZ_rgb[:,:,::-1]
plt.subplot(132);plt.imshow(img_NZ_rgb);plt.title("Color Image");
